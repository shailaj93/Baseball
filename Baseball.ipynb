# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\AYUSHI\Desktop\Flip Robo\Data Trained Projects\Evaluation Projects\baseball.csv")

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
df.corr()['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [markdown]
# ### We see that SV is the most positively related factor contributing to winning followed by BB, SHO and so on as it is in descending order. AB onwards the factors are negatively correlated means when one increases other will decrease.

# %%
import matplotlib.pyplot as plt  
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.plot(kind='density',subplots=True,layout=(6,6),sharex=False,legend=False, fontsize=1,figsize=(18,12))
plt.show()

# %% [markdown]
# ### In the plots we see that some of the factors are skewed, thus we need to find skewness

# %%
x=df.drop("W",axis=1)
y=df["W"]

# %%
x.skew().sort_values(ascending=False)
# Out:
# R      1.200786
# E      0.890132
# CG     0.736845
# H      0.670254
# SV     0.657524
# SHO    0.565790
# HR     0.516441
# SB     0.479893
# AB     0.183437
# BB     0.158498
# 3B     0.129502
# ER     0.058710
# ERA    0.053331
# RA     0.045734
# SO    -0.156065
# 2B    -0.230650
# dtype: float64

# %% [markdown]
# ### Now to bring the data in uniform distribution, we have to bring down the skewness in the range of (-0.5,0.5)

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x.skew().sort_values(ascending=False)
# Out:
# E      0.063909
# SO     0.041170
# SHO    0.006560
# ERA    0.001746
# SV     0.000836
# R      0.000000
# AB     0.000000
# H      0.000000
# HR    -0.000065
# ER    -0.001940
# BB    -0.007760
# RA    -0.008082
# SB    -0.010455
# 2B    -0.035315
# CG    -0.059785
# 3B    -0.072933
# dtype: float64

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
sk[np.abs(sk)>0.25].all()
# Out:
# True

# %% [markdown]
# ### Now we need to check whether outliers are present in the data or not. For that we need to check if the z value of all the factors are exceeding the range (-3,3)

# %%
x.iloc[:,0:11].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
from scipy.stats import zscore
(np.abs(zscore(x))<3).all()
# Out:
# False

# %% [markdown]
# ## Here we see all the factors are controlled are in the range of (-3,3).There are not many outliers

# %% [markdown]
# ### To predict the Winning W factor, we need to do linear regression modelling

# %%
from sklearn.model_selection import train_test_split
import warnings 
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.metrics import r2_score

# %%
for i in range (0,35) :
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    pred_train=lr.predict(x_train)
    print(f"at random state {i},the training accuracy is :{r2_score(y_train,pred_train)}")
    print(f"at random state {i},the testing accuracy is :{r2_score(y_test,pred_test)}") 
    print("\n")
# Out:
# at random state 0,the training accuracy is :0.9403063127554103
# at random state 0,the testing accuracy is :-2.5878965862579832
#
#
# at random state 1,the training accuracy is :0.9420691103856618
# at random state 1,the testing accuracy is :0.29799295994243546
#
#
# at random state 2,the training accuracy is :0.9326889486944724
# at random state 2,the testing accuracy is :-0.4411360263276902
#
#
# at random state 3,the training accuracy is :0.9189535009772185
# at random state 3,the testing accuracy is :0.3218325022154698
#
#
# at random state 4,the training accuracy is :0.8652532206229739
# at random state 4,the testing accuracy is :0.6416095875021939
#
#
# at random state 5,the training accuracy is :0.8742398340434931
# at random state 5,the testing accuracy is :0.7732211489189456
#
#
# at random state 6,the training accuracy is :0.8925741384943692
# at random state 6,the testing accuracy is :0.403831434847963
#
#
# at random state 7,the training accuracy is :0.8937103669387285
# ...

# %% [markdown]
# ### At random state 14 the testing and training accuracy is the closest

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=14)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.7986723361638315

# %% [markdown]
# ### Here we see the model accuracy is approximately 80% which is very good. Lets check for overfitting and if we can improve the accuracy

# %% [markdown]
# ## CROSS VALIDATION

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f'At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy}and accuracy score for testing is {Test_accuracy}')
    print('\n')
# Out:
# At cross fold 2 the cv score is -6.41975633806832 and accuracy score for training is -0.9382630410499933and accuracy score for testing is 0.7986723361638315
#
#
# At cross fold 3 the cv score is -1.6344953701198517 and accuracy score for training is -0.9382630410499933and accuracy score for testing is 0.7986723361638315
#
#
# At cross fold 4 the cv score is -0.28839267362995535 and accuracy score for training is -0.9382630410499933and accuracy score for testing is 0.7986723361638315
#
#
# At cross fold 5 the cv score is -1.4228754457348112 and accuracy score for training is -0.9382630410499933and accuracy score for testing is 0.7986723361638315
#
#
# At cross fold 6 the cv score is -0.8835593699171825 and accuracy score for training is -0.9382630410499933and accuracy score for testing is 0.7986723361638315
#
#
# At cross fold 7 the cv score is -1.491652184578383 and accuracy score for training is -0.9382630410499933and accuracy score for testing is 0.7986723361638315
#
#
# ...

# %% [markdown]
# ### Here we see the training accuracy is 93.82% and testing accuracy is 79.8%, Considering k=4 or cv=4 as for this value the cv score is the least negative

# %% [markdown]
# ## Plot the Data

# %%
import matplotlib.pyplot as plt 

plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_test,color='r')
plt.plot(y_test,y_test,color='b')
plt.title("Linear Regression")
plt.show()

# %% [markdown]
# ### Here we see that many points are close to the axis and the model will be able to predict winning score in a better way

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.8283257903295164

# %% [markdown]
# ### Through Lasso Regularization technique, we were able to raise the model accuracy to 82.8%

# %%
cv_score=cross_val_score(ls,x,y,cv=4)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.6203776028344838

# %% [markdown]
# ### Here we see that cross validation score is 62% and the training model accuracy is 82% which means there is slight overfitting as we have very less data to train and test the model.

# %% [markdown]
# ## Ensemble technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='log2')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision=rf.predict(x_test)


rfs=r2_score(y_test,pred_decision)
print('R2 score:',rfs*100)

rfscore=cross_val_score(rf,x,y,cv=4)
rfc=rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 score: 70.44185890834194
# Cross Val Score: 37.18324599782286

# %% [markdown]
# ### we are getting our testing model accuracy as 70% which shows that the 16 factors used to predict the winning of the match is important as it does depend on the 16 factors. Also model has good accuracy and cross validation score as 37% which is less because we just have 30 data points and its too less to test and train the data

# %% [markdown]
# ### A high R2 score or training score and low cross validation score shows overfitting. Also overfitting subjects to high variance which explains the difference between 70% and 37%. This data is too less to train the model. We will need more data points.
# ### But one thing is concludable that the number of wins for a given team in the 2015 season is definitely based on several different 16 indicators of success

# %%
import pickle

# %%
filename='Baseball.pkl'
pickle.dump(rf, open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
loaded_model= pickle.load(open('Baseball.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.7044185890834194

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["predicted","original"])
conclusion
# Out:
#                0      1      2      3      4      5
# predicted  87.42  73.92  91.05  78.04  88.81  78.90
# original   87.17  74.11  90.39  77.05  90.38  78.93
